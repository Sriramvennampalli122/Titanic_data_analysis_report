# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("cleaned_titanic.csv")

# %%
sns.countplot(data=df,x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [raw]
# This bar graph will show the number of survivors and non-survivors, helping us visualize the survival rate on the Titanic.

# %%
sns.countplot(data=df,x="survived",hue="sex")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [raw]
# This bar graph reveals that more women survived compared to men on the Titanic. By using the hue parameter, we can easily compare the survival rates between different groups.

# %%
sns.barplot(x="sex",y="age",hue="survived",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [raw]
# Analysis:
# The x-axis represents the sex category (male and female).
# The y-axis represents the average age of passengers.
# The hue (color differentiation) represents survival status (0 for not survived and 1 for survived).
# The plot shows that the average age of survivors was higher than that of non-survivors for both males and females.

# %%
sns.countplot(x="class",hue="sex",data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [raw]
# Analysis:
# The x-axis represents the class category (first, second and third).
# The y-axis represents the number of passengers.
# The hue (color differentiation) represents sex (blue for males and orange for females).
# The plot shows that the number of passangers in each class for both males and females.

# %%
df.head(10).plot(kind="bar",stacked=True)
# Out:
# <Axes: >

# %% [raw]
# Analysis:
# The stacked bar chart helps compare sepal length, sepal width, petal length, and petal width across different flower species.
# It allows us to see how these attributes differ among the first 10 samples.

# %%
df["class"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [raw]
# This pie chart shows the percentage of passengers in each class. We can see that the majority of passengers were traveling in Third Class, followed by First Class and Second Class.

# %%
sns.stripplot(x="class",y="age",hue="sex",data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [raw]
# Analysis:
# The x-axis represents passenger class (First, Second, Third).
# The y-axis represents age.
# The hue differentiates between male and female passengers.
# The distribution of age in different classes can be seen, with First-Class passengers tending to be older compared to Second and Third-Class passengers.
# Key Observations:
# First-class passengers were generally older.
# Third-class passengers were younger on average.
# Strip plots help us see data distribution within each category.

# %%
x1=pd.crosstab(df["class"],df["survived"])
sns.heatmap(x1,annot=True,fmt=".1f")
# Out:
# <Axes: xlabel='survived', ylabel='class'>

# %% [raw]
# Analysis:
# The rows represent passenger classes (First, Second, Third).
# The columns represent survival status (0 for not survived, 1 for survived).
# The values inside the boxes represent the number of passengers in each category.
# The color intensity indicates the concentration of values. Lighter shades represent higher values, and darker shades represent lower values.
# Third-class passengers had the highest number of non-survivors (372), while First-class had the highest number of survivors (136).

# %%
x2=pd.crosstab(df["sex"],df["survived"])
sns.heatmap(x2,annot=True,fmt=".1f")
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
x3=pd.crosstab(df["sex"],df["survived"])
sns.heatmap(x3,annot=True,fmt=".1f")
# Out:
# <Axes: xlabel='survived', ylabel='sex'>
