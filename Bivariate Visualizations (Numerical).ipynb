# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("cleaned_titanic.csv")

# %%
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 842         885         0       3  female  39.0      0      5  29.1250
# 843         887         1       1  female  19.0      0      0  30.0000
# 844         888         0       3  female  22.5      1      2  23.4500
# 845         889         1       1    male  26.0      0      0  30.0000
# 846         890         0       3    male  32.0      0      0   7.7500
#
#     embarked  class    who  adult_male  embark_town alive  alone
# ...

# %%
sns.scatterplot(x="class",y="fare",hue="age",style="sex",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [raw]
# Interpretation:
#
# Colors indicate age of passanger
# Different markers (dots/crosses) indicate male vs. female.
# They used to charge different prices to based of age and sex

# %%
sns.jointplot(x="class",y="fare",data=df)

# %% [raw]
# Interpretation:
#
# The scatter plot in the center shows the relationship between class and fare
# The histogram at the top shows the distribution of class.
# The histogram on the right shows the distribution of fair

# %%
sns.lineplot(x="age",y="fare",data=df.head(20))
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [raw]
# Interpretation:
#
# The line plot shows how the price changed over age.
# There is an increment in prices over the years till 50's and there decreased over the age.
